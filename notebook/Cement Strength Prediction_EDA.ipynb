# %% [markdown]
# ## 1. Problem Statement
#
# * This project predicts the strength of the cement.

# %% [markdown]
# ## 2. Data Collection
#
# * Data Source: https://www.kaggle.com/datasets/maajdl/yeh-concret-data

# %% [markdown]
# ## 3. Know Your Data

# %% [markdown]
# ### 3.1 Import Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 3.2 Dataset Loading

# %%
df = pd.read_csv('Concrete_Data.csv')

# %% [markdown]
# ### 3.3 Dataset First View

# %%
df.head()
# Out:
#    cement   slag  flyash  water  superplasticizer  coarseaggregate  \
# 0   540.0    0.0     0.0  162.0               2.5           1040.0
# 1   540.0    0.0     0.0  162.0               2.5           1055.0
# 2   332.5  142.5     0.0  228.0               0.0            932.0
# 3   332.5  142.5     0.0  228.0               0.0            932.0
# 4   198.6  132.4     0.0  192.0               0.0            978.4
#
#    fineaggregate  age  csMPa
# 0          676.0   28  79.99
# 1          676.0   28  61.89
# 2          594.0  270  40.27
# 3          594.0  365  41.05
# 4          825.5  360  44.30

# %% [markdown]
# ### 3.4 Dataset Rows & Columns count

# %%
df.shape
# Out:
# (1030, 9)

# %% [markdown]
# ### 3.5 Dataset Information
# * Cement (component 1) -- quantitative -- kg in a m3 mixture -- Input Variable
# * Blast Furnace Slag (component 2) -- quantitative -- kg in a m3 mixture -- Input Variable
# * Fly Ash (component 3) -- quantitative -- kg in a m3 mixture -- Input Variable
# * Water (component 4) -- quantitative -- kg in a m3 mixture -- Input Variable
# * Superplasticizer (component 5) -- quantitative -- kg in a m3 mixture -- Input Variable
# * Coarse Aggregate (component 6) -- quantitative -- kg in a m3 mixture -- Input Variable
# * Fine Aggregate (component 7) -- quantitative -- kg in a m3 mixture -- Input Variable
# * Age -- quantitative -- Day (1~365) -- Input Variable
# * Concrete compressive strength -- quantitative -- MPa -- Output Variable

# %% [markdown]
# ## 4. Understanding Variables

# %% [markdown]
# ### 4.1 Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 25

# %% [markdown]
# There are 25 duplicate values in the dataset.

# %% [markdown]
# ### 4.2 Dropping Duplicate Values

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### 4.3 Missing/Null Values

# %%
df.isnull().sum()
# Out:
# cement              0
# slag                0
# flyash              0
# water               0
# superplasticizer    0
# coarseaggregate     0
# fineaggregate       0
# age                 0
# csMPa               0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset.

# %% [markdown]
# ### 4.4 Variable Data Type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cement            1030 non-null   float64
#  1   slag              1030 non-null   float64
#  2   flyash            1030 non-null   float64
#  3   water             1030 non-null   float64
#  4   superplasticizer  1030 non-null   float64
#  5   coarseaggregate   1030 non-null   float64
#  6   fineaggregate     1030 non-null   float64
#  7   age               1030 non-null   int64
#  8   csMPa             1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %% [markdown]
# ### 4.5 Unique Values for each variable

# %%
df.nunique()
# Out:
# cement              278
# slag                185
# flyash              156
# water               195
# superplasticizer    111
# coarseaggregate     284
# fineaggregate       302
# age                  14
# csMPa               845
# dtype: int64

# %% [markdown]
# ### 4.6 Statistics of Dataset

# %%
df.describe().transpose()
# Out:
#                    count        mean         std     min      25%      50%  \
# cement            1030.0  281.167864  104.506364  102.00  192.375  272.900
# slag              1030.0   73.895825   86.279342    0.00    0.000   22.000
# flyash            1030.0   54.188350   63.997004    0.00    0.000    0.000
# water             1030.0  181.567282   21.354219  121.80  164.900  185.000
# superplasticizer  1030.0    6.204660    5.973841    0.00    0.000    6.400
# coarseaggregate   1030.0  972.918932   77.753954  801.00  932.000  968.000
# fineaggregate     1030.0  773.580485   80.175980  594.00  730.950  779.500
# age               1030.0   45.662136   63.169912    1.00    7.000   28.000
# csMPa             1030.0   35.817961   16.705742    2.33   23.710   34.445
#
#                        75%     max
# cement             350.000   540.0
# slag               142.950   359.4
# flyash             118.300   200.1
# water              192.000   247.0
# superplasticizer    10.200    32.2
# ...

# %% [markdown]
# ## 5. Data Visualization

# %% [markdown]
# ### 5.1 Univariate Analysis

# %%
# Distribution of each variable
for col in df.columns:
    plt.figure(figsize=(10,8))
    sns.histplot(df[col],kde=True)
    plt.show()

# %% [markdown]
# ### 5.2 Bivariate Analysis

# %%
# Checking for correlation using heatmap visualization
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# Pairplot Visualization
sns.pairplot(df,diag_kind='kde')
plt.show()
